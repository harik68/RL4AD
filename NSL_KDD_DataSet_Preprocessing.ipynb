# %%
"""
This python script does the following:
1. Loads NSL_KDD_Dataset from a file
2. Convert every continuous variable x into categorical by binnig. 
   Here a quantile based binning is used
   0.0 <= x < 0.2 : 1
   0.2 <= x < 0.4 : 2
   0.4 <= x < 0.6 : 3
   0.6 <= x < 0.8 : 4
   0.8 <= x < 1.0 : 5
3. Convert all categorical variables to boolean using one hot encoding
4. Write the resulting output into a file after compressing using pickle
"""
# Out:
# '\nThis python script does the following:\n1. Loads NSL_KDD_Dataset from a file\n2. Convert every continuous variable x into categorical by binnig. Here a quantile based binning is used\n   - x < 0.2 : low\n   - 0.2 <= x < 0.4: low_medium\n   - 0.4 <= x\n'

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing

# %%
# File containing NSL_KDD_DataSet
f = '/Users/harikoduvely/Projects/RL/NSL_KDD_DataSet/Small_Training_Set.csv'

# %%
# Column Names for NSL_KDD_DataSet
nsl_kdd_columns = ['duration',
'protocol_type',
'service',
'flag',
'src_bytes',
'dst_bytes',
'land',
'wrong_fragment',
'urgent',
'hot',
'num_failed_logins',
'logged_in',
'num_compromised',
'root_shell',
'su_attempted',
'num_root',
'num_file_creations',
'num_shells',
'num_access_files',
'num_outbound_cmds',
'is_host_login',
'is_guest_login',
'count',
'srv_count',
'serror_rate',
'srv_serror_rate',
'rerror_rate',
'srv_rerror_rate',
'same_srv_rate',
'diff_srv_rate',
'srv_diff_host_rate',
'dst_host_count',
'dst_host_srv_count',
'dst_host_same_srv_rate',
'dst_host_diff_srv_rate',
'dst_host_same_src_port_rate',
'dst_host_srv_diff_host_rate',
'dst_host_serror_rate',
'dst_host_srv_serror_rate',
'dst_host_rerror_rate',
'dst_host_srv_rerror_rate',
'attack_type',
'no_correctly_classified']

# %%
# Load Data
df_nsl = pd.read_csv(f,header=None, names=nsl_kdd_columns)

# %%
# Dropping the column 'no_correctly_classified'
df_nsl = df_nsl.drop(['no_correctly_classified'], axis=1)

# %%
# Split Numeric and Categorical Variables
df_nsl_cat = df_nsl.select_dtypes(include=[object])

# %%
df_nsl_num = df_nsl.select_dtypes(exclude=[object])

# %%
# Keeping the attack_type in a separate dataframe (no need to one hot encode this)
df_nsl_attack_type = df_nsl_cat.drop(['protocol_type','service','flag'], axis=1)

# %%
df_nsl_cat = df_nsl_cat.drop(['attack_type'], axis=1)

# %%
# Keeping the binary variables in a separate dataframe (no need to bin these)
df_nsl_bin = df_nsl_num[['logged_in','is_host_login','is_guest_login','root_shell','urgent','su_attempted']]

# %%
df_nsl_cont= df_nsl_num.drop(['logged_in','is_host_login','is_guest_login','root_shell','urgent','su_attempted'], axis=1)

# %%
# Discretizing continuous variables using binning
def quantile_discret(x, q2, q4, q6, q8):
    # _1  : low 
    # _2 : Low_Medium
    # _3  : Medium
    # _4 : High_Medium
    # _5  : High
    if x < q2:
        y = 1
    elif (x >= q2 and x < q4):
        y = 2
    elif (x >= q4 and x < q6):
        y = 3
    elif (x >= q6 and x < q8):
        y = 4
    else:
        y = 5

    return y

# %%
colnames_nsl_cont = list(df_nsl_cont)

# %%
for name in colnames_nsl_cont:
    new_name = 'disc_' + name
    q2 = df_nsl_cont[name].quantile(0.2)
    q4 = df_nsl_cont[name].quantile(0.4)
    q6 = df_nsl_cont[name].quantile(0.6)
    q8 = df_nsl_cont[name].quantile(0.8)
    df_nsl_cont[new_name] = df_nsl_cont[name].apply(quantile_discret, args=(q2, q4, q6, q8))

# %%
df_nsl_disc = df_nsl_cont.drop(colnames_nsl_cont, axis=1)

# %%
df_nsl_disc.head()
# Out:
#    disc_duration  disc_src_bytes  disc_dst_bytes  disc_land  \
# 0              5               5               3          5
# 1              5               3               3          5
# 2              5               3               3          5
# 3              5               4               5          5
# 4              5               4               4          5
#
#    disc_wrong_fragment  disc_hot  disc_num_failed_logins  \
# 0                    5         5                       5
# 1                    5         5                       5
# 2                    5         5                       5
# 3                    5         5                       5
# 4                    5         5                       5
#
#    disc_num_compromised  disc_num_root  disc_num_file_creations  \
# 0                     5              5                        5
# 1                     5              5                        5
# 2                     5              5                        5
# 3                     5              5                        5
# 4                     5              5                        5
#
#                ...                disc_dst_host_count  \
# 0              ...                                  2
# 1              ...                                  5
# 2              ...                                  5
# 3              ...                                  1
# 4              ...                                  5
#
#    disc_dst_host_srv_count  disc_dst_host_same_srv_rate  \
# 0                        3                            3
# 1                        1                            1
# 2                        3                            3
# 3                        5                            5
# 4                        5                            5
#
#    disc_dst_host_diff_srv_rate  disc_dst_host_same_src_port_rate  \
# 0                            3                                 4
# 1                            5                                 5
# 2                            4                                 3
# 3                            2                                 4
# 4                            2                                 3
#
#    disc_dst_host_srv_diff_host_rate  disc_dst_host_serror_rate  \
# 0                                 4                          4
# 1                                 4                          4
# 2                                 4                          5
# 3                                 5                          4
# 4                                 4                          4
#
#    disc_dst_host_srv_serror_rate  disc_dst_host_rerror_rate  \
# 0                              4                          5
# 1                              4                          5
# 2                              5                          5
# 3                              4                          5
# 4                              4                          5
#
#    disc_dst_host_srv_rerror_rate
# 0                              5
# 1                              5
# 2                              5
# 3                              5
# 4                              5
#
# [5 rows x 32 columns]

# %%
for name in list(df_nsl_num):
    print(name, df_nsl_num[name].describe())
# Out:
# ('duration', count     1011.000000
# mean       311.960435
# std       2554.352933
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      41285.000000
# Name: duration, dtype: float64)
# ('src_bytes', count    1.011000e+03
# mean     7.874637e+03
# std      1.754888e+05
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      4.100000e+01
# 75%      2.675000e+02
# max      5.131424e+06
# Name: src_bytes, dtype: float64)
# ('dst_bytes', count      1011.000000
# mean       1449.090010
# std        5854.309216
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%         537.500000
# max      148722.000000
# Name: dst_bytes, dtype: float64)
# ('land', count    1011.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: land, dtype: float64)
# ('wrong_fragment', count    1011.000000
# mean        0.033630
# std         0.312854
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         3.000000
# Name: wrong_fragment, dtype: float64)
# ('urgent', count    1011.000000
# mean        0.000989
# std         0.031450
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: urgent, dtype: float64)
# ('hot', count    1011.000000
# mean        0.179031
# std         1.903253
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        30.000000
# Name: hot, dtype: float64)
# ('num_failed_logins', count    1011.000000
# mean        0.002967
# std         0.070297
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         2.000000
# Name: num_failed_logins, dtype: float64)
# ('logged_in', count    1011.000000
# mean        0.392681
# std         0.488588
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: logged_in, dtype: float64)
# ('num_compromised', count    1011.000000
# mean        0.058358
# std         0.706096
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        19.000000
# Name: num_compromised, dtype: float64)
# ('root_shell', count    1011.000000
# mean        0.005935
# std         0.076846
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: root_shell, dtype: float64)
# ('su_attempted', count    1011.000000
# mean        0.000989
# std         0.031450
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: su_attempted, dtype: float64)
# ('num_root', count    1011.000000
# mean        0.045500
# std         0.667422
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        14.000000
# Name: num_root, dtype: float64)
# ('num_file_creations', count    1011.000000
# mean        0.012859
# std         0.261058
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         8.000000
# Name: num_file_creations, dtype: float64)
# ('num_shells', count    1011.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: num_shells, dtype: float64)
# ('num_access_files', count    1011.000000
# mean        0.004946
# std         0.070186
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: num_access_files, dtype: float64)
# ('num_outbound_cmds', count    1011.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: num_outbound_cmds, dtype: float64)
# ('is_host_login', count    1011.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: is_host_login, dtype: float64)
# ('is_guest_login', count    1011.000000
# mean        0.006924
# std         0.082962
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: is_guest_login, dtype: float64)
# ('count', count    1011.000000
# mean       80.779426
# std       108.185429
# min         1.000000
# 25%         2.000000
# 50%        12.000000
# 75%       142.500000
# max       511.000000
# Name: count, dtype: float64)
# ('srv_count', count    1011.000000
# mean       22.793274
# std        60.863000
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        16.000000
# max       511.000000
# Name: srv_count, dtype: float64)
# ('serror_rate', count    1011.000000
# mean        0.291929
# std         0.452039
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: serror_rate, dtype: float64)
# ('srv_serror_rate', count    1011.000000
# mean        0.290346
# std         0.452073
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: srv_serror_rate, dtype: float64)
# ('rerror_rate', count    1011.000000
# mean        0.129852
# std         0.333451
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: rerror_rate, dtype: float64)
# ('srv_rerror_rate', count    1011.000000
# mean        0.131701
# std         0.336948
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: srv_rerror_rate, dtype: float64)
# ('same_srv_rate', count    1011.000000
# mean        0.646775
# std         0.442226
# min         0.000000
# 25%         0.080000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: same_srv_rate, dtype: float64)
# ('diff_srv_rate', count    1011.000000
# mean        0.069080
# std         0.188939
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.060000
# max         1.000000
# Name: diff_srv_rate, dtype: float64)
# ('srv_diff_host_rate', count    1011.000000
# mean        0.090049
# std         0.250199
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: srv_diff_host_rate, dtype: float64)
# ('dst_host_count', count    1011.000000
# mean      179.461919
# std       100.718209
# min         1.000000
# 25%        73.500000
# 50%       255.000000
# 75%       255.000000
# max       255.000000
# Name: dst_host_count, dtype: float64)
# ('dst_host_srv_count', count    1011.000000
# mean      108.097923
# std       110.526908
# min         1.000000
# 25%         9.000000
# 50%        44.000000
# 75%       255.000000
# max       255.000000
# Name: dst_host_srv_count, dtype: float64)
# ('dst_host_same_srv_rate', count    1011.000000
# mean        0.500227
# std         0.451589
# min         0.000000
# 25%         0.040000
# 50%         0.360000
# 75%         1.000000
# max         1.000000
# Name: dst_host_same_srv_rate, dtype: float64)
# ('dst_host_diff_srv_rate', count    1011.000000
# mean        0.079515
# std         0.177182
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.070000
# max         1.000000
# Name: dst_host_diff_srv_rate, dtype: float64)
# ('dst_host_same_src_port_rate', count    1011.000000
# mean        0.159308
# std         0.319927
# min         0.000000
# 25%         0.000000
# 50%         0.010000
# 75%         0.080000
# max         1.000000
# Name: dst_host_same_src_port_rate, dtype: float64)
# ('dst_host_srv_diff_host_rate', count    1011.000000
# mean        0.034263
# std         0.115499
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.020000
# max         1.000000
# Name: dst_host_srv_diff_host_rate, dtype: float64)
# ('dst_host_serror_rate', count    1011.000000
# mean        0.292987
# std         0.450795
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: dst_host_serror_rate, dtype: float64)
# ('dst_host_srv_serror_rate', count    1011.000000
# mean        0.288615
# std         0.450847
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: dst_host_srv_serror_rate, dtype: float64)
# ('dst_host_rerror_rate', count    1011.000000
# mean        0.119624
# std         0.305578
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: dst_host_rerror_rate, dtype: float64)
# ('dst_host_srv_rerror_rate', count    1011.000000
# mean        0.129169
# std         0.329947
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: dst_host_srv_rerror_rate, dtype: float64)

# %%
df_nsl['duration'].describe()
# Out:
# count     1011.000000
# mean       311.960435
# std       2554.352933
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      41285.000000
# Name: duration, dtype: float64

# %%
enc = preprocessing.OneHotEncoder()

# %%
enc.fit(df_nsl_disc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-ae9927d9aa61> in <module>()
# ----> 1 enc.fit(df_nsl_disc)
#
# /Applications/anaconda/envs/tf-env/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in fit(self, X, y)
#    1842         self
#    1843         """
# -> 1844         self.fit_transform(X)
#    1845         return self
#    1846
#
# /Applications/anaconda/envs/tf-env/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in fit_transform(self, X, y)
#    1900         """
#    1901         return _transform_selected(X, self._fit_transform,
# -> 1902                                    self.categorical_features, copy=True)
#    1903
#    1904     def _transform(self, X):
#
# /Applications/anaconda/envs/tf-env/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in _transform_selected(X, transform, selected, copy)
#    1695     X : array or sparse matrix, shape=(n_samples, n_features_new)
#    1696     """
# -> 1697     X = check_array(X, accept_sparse='csc', copy=copy, dtype=FLOAT_DTYPES)
#    1698
#    1699     if isinstance(selected, six.string_types) and selected == "all":
#
# /Applications/anaconda/envs/tf-env/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     422                              " a minimum of %d is required%s."
#     423                              % (n_features, shape_repr, ensure_min_features,
# --> 424                                 context))
#     425
#     426     if warn_on_dtype and dtype_orig is not None and array.dtype != dtype_orig:
#
# ValueError: Found array with 0 feature(s) (shape=(1011, 0)) while a minimum of 1 is required.
